# %% [markdown]
# <a href="https://colab.research.google.com/github/kevintorres11/PROBABILIDAD-Y-ESTADISTICA-9-10/blob/main/PRACTICA_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Estadistica descriptiva del Dataset Autos
#
# Kevin Torres Acosta
#
# En esta practica realizaremos un analisis estaditico descriptivo del dataset de automoviles, utilizando medidas de tendencia central, histogramas y diagramas de caja para analizar el comportamiento del precio de los autos.

# %%
# Importar libreria
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
autos = pd.read_csv("/autos2.csv")
autos.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
autos = autos.dropna(subset=["price"])
autos["price"] = pd.to_numeric(autos["price"])
autos["price"].min()
autos["price"].max()
autos["price"].mode()
autos["price"].mean()
autos["price"].median()
autos["price"].std()
autos["price"].describe()
# Out:
# count      201.000000
# mean     13207.129353
# std       7947.066342
# min       5118.000000
# 25%       7775.000000
# 50%      10295.000000
# 75%      16500.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
n = autos["price"].count()
bins = int(1 + 3.322 * np.log10(n))
bins
# Out:
# 8

# %%
plt.hist(autos["price"], bins=bins)
plt.title("Histograma de Precios de Automóviles")
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.show()

# %%
sns.boxplot(x="body-style", y="price", data=autos)
plt.title("Precio vs Tipo de Vehículo")
plt.xlabel("Tipo de Vehículo")
plt.ylabel("Precio")
plt.show()

# %%
sns.boxplot(x="drive-wheels", y="price", data=autos)
plt.title("Precio vs Tipo de Tracción")
plt.xlabel("Tracción")
plt.ylabel("Precio")
plt.show()

# %%
sns.boxplot(x="engine-location", y="price", data=autos)
plt.title("Precio vs Ubicación del Motor")
plt.xlabel("Ubicación del Motor")
plt.ylabel("Precio")
plt.show()

# %% [markdown]
# 6. Conclusiones generales
#
# El precio de los automóviles presenta una distribución asimétrica.
#
# Existen valores atípicos en los precios más altos.
#
# El tipo de vehículo influye significativamente en el precio.
#
# Los autos con tracción trasera y motor trasero tienden a tener precios más elevados.
#
# Los diagramas de caja facilitan la comparación visual entre categorías.
